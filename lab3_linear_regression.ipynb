# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset from URL (e.g., student scores dataset)
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
data = pd.read_csv(url)

# Display first 5 rows
print("Input Data:")
print(data.head())

# Extract features and target
X = data['Hours'].values
y = data['Scores'].values

# Reshape X for matrix operations
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# Add intercept term (bias)
X_b = np.c_[np.ones((len(X), 1)), X]  # add x0 = 1 to each instance

# Linear regression formula: theta = (X^T * X)^-1 * X^T * y
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# Make predictions
y_pred = X_b.dot(theta_best)

# Performance: Mean Squared Error
mse = np.mean((y - y_pred) ** 2)

print("\nModel Coefficients:")
print(f"Intercept (θ₀): {theta_best[0][0]:.4f}")
print(f"Slope (θ₁): {theta_best[1][0]:.4f}")
print(f"Mean Squared Error: {mse:.4f}")

# Plot
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', label='Predicted Line')
plt.xlabel('Hours Studied')
plt.ylabel('Scores')
plt.title('Linear Regression Fit')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Input Data:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
#
# Model Coefficients:
# Intercept (θ₀): 2.4837
# Slope (θ₁): 9.7758
# Mean Squared Error: 28.8827
